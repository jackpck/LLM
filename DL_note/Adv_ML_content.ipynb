# %% [markdown]
# # 1. Deep Learning
#
# ## Optimization
# - Proximal optimization
#     - natural gradient
#     - damped Newton method
# - Stochastic gradient descent
# - RMSprop
# - Adagrad
# - Adam
#
# ## High dimensional learning
# - Saddle point and second-order learning
#
# ## Neural network training best practices
# - batch norm
# - batch size
# - learning rate and schedule
# - dropout
# - skip-connection
# - weight initialization
# - activation function
#
# ## Neural network as iterative function
# - order-to-chaos transition
# - forward and backward propagation
# - gradient vanishing and explosion
# - rank-collapse in attention
#
# ## Mathematical foundation
# - Hessian matrix
# - Gauss-Newton matrix
# - Fisher Information Matrix
#
# # 2. NLP
#
# ## Different transformer paradigm (training objectives)
# - autoencoding
# - autoregressive
# - permutation
# - strengths and weaknesses of different training objectives
#
# ## Transformer in detail
# - tokenizer
# - positional encoding
# - attention mechanism
# - multi-head attention
# - skip-connection
# - layernorm
# - MLP
#
# ## Training
# - fine-tuning LLM
# - prompt engineering
#
# ## NLP use cases
# - topic modeling
# - NER
# - chatbot (Q&A)
#
# # 3. Bayesian methods
#
# ## LDA, DP, HDP
#
# ## Bayesian network
#
# ## Markov random field, conditional random field
# - Restricted Boltzmann Machine
#
# ## Inference methods
# - Expectation-Maximization (MFT)
# - Belief propagation (Bethe approximation)
# - MCMC
#
# # 4. Misc
#
# ## Kernel learning
#
# ## Graph neural network
#
# ## Overparametrization
